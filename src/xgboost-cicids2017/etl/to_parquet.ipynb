# %%
import pandas as pd
import os

# %%
import os
import pyarrow as pa
import pyarrow.csv as pc_csv
import pyarrow.compute as pc_compute
import pyarrow.parquet as pq

def dict_encode_all_str_columns(table: pa.Table) -> pa.Table:
    """
    Dictionary encodes all string columns in the given PyArrow table.

    Args:
        table (pa.Table): The input PyArrow table.

    Returns:
        pa.Table: A new PyArrow table with string columns dictionary encoded.
    """
    new_columns = []
    for field in table.schema:
        column = table[field.name]
        if pa.types.is_string(field.type):
            encoded_column = pc_compute.dictionary_encode(column)
            new_columns.append(encoded_column)
            print(f"   Encoded column '{field.name}' as dictionary.")
        else:
            new_columns.append(column)
    return pa.Table.from_arrays(new_columns, names=table.column_names)

def to_parquet(project_path: str) -> None:
    """
    Converts CSV files for each day of the week into dictionary-encoded Parquet files.

    Args:
        project_path (str): The base path of the project containing the data.
    """
    days = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']
    data_dir = os.path.join(project_path, 'data', 'cicids2017')

    for day in days:
        csv_file = os.path.join(data_dir, f'{day}.csv')
        parquet_file = os.path.join(data_dir, f'{day}.parquet')
        print(f"Loading data for {day}: {csv_file}")

        try:
            # Read CSV into a PyArrow Table
            table = pc_csv.read_csv(csv_file)
            print(f"   Successfully read {csv_file} into PyArrow Table.")

            # Dictionary encode all string columns
            encoded_table = dict_encode_all_str_columns(table)

            # Write the encoded table to a Parquet file
            pq.write_table(encoded_table, parquet_file)
            print(f"   Successfully transformed {csv_file} to {parquet_file}\n")

        except FileNotFoundError:
            print(f"   File not found: {csv_file}. Skipping {day}.\n")
        except Exception as e:
            print(f"   Error transforming {csv_file} to Parquet: {e}. Skipping {day}.\n")

# Example usage:
# to_parquet('/path/to/your/project')

# %%
def print_file_size(path: str) -> None:
    for file in os.listdir(path):
        print(f"   {file}: {(os.path.getsize(os.path.join(path, file)) / 1_048_576):.0f} MB")

# %%
project_path = '/home/tan/Code/finalproject/xgboost-cicids2017'

# Step 1: Load Data
df = to_parquet(project_path)
# Out:
# Loading data for monday: /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/monday.csv
#    Successfully read /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/monday.csv into PyArrow Table.
#    Encoded column 'Flow ID' as dictionary.
#    Encoded column 'Src IP' as dictionary.
#    Encoded column 'Dst IP' as dictionary.
#    Encoded column 'Label' as dictionary.
#    Successfully transformed /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/monday.csv to /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/monday.parquet
#
# Loading data for tuesday: /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/tuesday.csv
#    Successfully read /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/tuesday.csv into PyArrow Table.
#    Encoded column 'Flow ID' as dictionary.
#    Encoded column 'Src IP' as dictionary.
#    Encoded column 'Dst IP' as dictionary.
#    Encoded column 'Label' as dictionary.
#    Successfully transformed /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/tuesday.csv to /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/tuesday.parquet
#
# Loading data for wednesday: /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/wednesday.csv
#    Successfully read /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/wednesday.csv into PyArrow Table.
#    Encoded column 'Flow ID' as dictionary.
#    Encoded column 'Src IP' as dictionary.
#    Encoded column 'Dst IP' as dictionary.
#    Encoded column 'Label' as dictionary.
#    Successfully transformed /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/wednesday.csv to /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/wednesday.parquet
#
# Loading data for thursday: /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/thursday.csv
#    Successfully read /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/thursday.csv into PyArrow Table.
#    Encoded column 'Flow ID' as dictionary.
#    Encoded column 'Src IP' as dictionary.
#    Encoded column 'Dst IP' as dictionary.
#    Encoded column 'Label' as dictionary.
#    Successfully transformed /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/thursday.csv to /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/thursday.parquet
#
# Loading data for friday: /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/friday.csv
#    Successfully read /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/friday.csv into PyArrow Table.
#    Encoded column 'Flow ID' as dictionary.
#    Encoded column 'Src IP' as dictionary.
#    Encoded column 'Dst IP' as dictionary.
#    Encoded column 'Label' as dictionary.
#    Successfully transformed /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/friday.csv to /home/tan/Code/finalproject/xgboost-cicids2017/data/cicids2017/friday.parquet

# %%
print_file_size(os.path.join(project_path, 'data', 'cicids2017'))
# Out:
#    friday.csv: 272 MB
#    wednesday.csv: 278 MB
#    thursday.parquet: 62 MB
#    tuesday.csv: 170 MB
#    monday.csv: 198 MB
#    wednesday.parquet: 88 MB
#    monday.parquet: 71 MB
#    tuesday.parquet: 62 MB
#    friday.parquet: 89 MB
#    thursday.csv: 181 MB

# %%
import pyarrow.parquet as pq

# %%
friday_table = pq.read_table(os.path.join(project_path, 'data', 'cicids2017', 'friday.parquet'))
print(friday_table.column_names)
# Out:
# ['id', 'Flow ID', 'Src IP', 'Src Port', 'Dst IP', 'Dst Port', 'Protocol', 'Timestamp', 'Flow Duration', 'Total Fwd Packet', 'Total Bwd packets', 'Total Length of Fwd Packet', 'Total Length of Bwd Packet', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd RST Flags', 'Bwd RST Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Packet Length Min', 'Packet Length Max', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'CWR Flag Count', 'ECE Flag Count', 'Down/Up Ratio', 'Average Packet Size', 'Fwd Segment Size Avg', 'Bwd Segment Size Avg', 'Fwd Bytes/Bulk Avg', 'Fwd Packet/Bulk Avg', 'Fwd Bulk Rate Avg', 'Bwd Bytes/Bulk Avg', 'Bwd Packet/Bulk Avg', 'Bwd Bulk Rate Avg', 'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'FWD Init Win Bytes', 'Bwd Init Win Bytes', 'Fwd Act Data Pkts', 'Fwd Seg Size Min', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'ICMP Code', 'ICMP Type', 'Total TCP Flow Time', 'Label', 'Attempted Category']

# %%
friday_table = friday_table.to_pandas()
friday_table.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547557 entries, 0 to 547556
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          547557 non-null  int64
#  1   Flow ID                     547557 non-null  category
#  2   Src IP                      547557 non-null  category
#  3   Src Port                    547557 non-null  int64
#  4   Dst IP                      547557 non-null  category
#  5   Dst Port                    547557 non-null  int64
#  6   Protocol                    547557 non-null  int64
#  7   Timestamp                   547557 non-null  datetime64[ns]
#  8   Flow Duration               547557 non-null  int64
#  9   Total Fwd Packet            547557 non-null  int64
#  10  Total Bwd packets           547557 non-null  int64
#  11  Total Length of Fwd Packet  547557 non-null  int64
#  12  Total Length of Bwd Packet  547557 non-null  int64
#  13  Fwd Packet Length Max       547557 non-null  int64
#  14  Fwd Packet Length Min       547557 non-null  int64
#  15  Fwd Packet Length Mean      547557 non-null  float64
#  16  Fwd Packet Length Std       547557 non-null  float64
#  17  Bwd Packet Length Max       547557 non-null  int64
#  18  Bwd Packet Length Min       547557 non-null  int64
#  19  Bwd Packet Length Mean      547557 non-null  float64
#  20  Bwd Packet Length Std       547557 non-null  float64
#  21  Flow Bytes/s                547557 non-null  float64
#  22  Flow Packets/s              547557 non-null  float64
#  23  Flow IAT Mean               547557 non-null  float64
#  24  Flow IAT Std                547557 non-null  float64
#  25  Flow IAT Max                547557 non-null  int64
#  26  Flow IAT Min                547557 non-null  int64
#  27  Fwd IAT Total               547557 non-null  int64
#  28  Fwd IAT Mean                547557 non-null  float64
#  29  Fwd IAT Std                 547557 non-null  float64
#  30  Fwd IAT Max                 547557 non-null  int64
#  31  Fwd IAT Min                 547557 non-null  int64
#  32  Bwd IAT Total               547557 non-null  int64
#  33  Bwd IAT Mean                547557 non-null  float64
#  34  Bwd IAT Std                 547557 non-null  float64
#  35  Bwd IAT Max                 547557 non-null  int64
#  36  Bwd IAT Min                 547557 non-null  int64
#  37  Fwd PSH Flags               547557 non-null  int64
#  38  Bwd PSH Flags               547557 non-null  int64
#  39  Fwd URG Flags               547557 non-null  int64
#  40  Bwd URG Flags               547557 non-null  int64
#  41  Fwd RST Flags               547557 non-null  int64
#  42  Bwd RST Flags               547557 non-null  int64
#  43  Fwd Header Length           547557 non-null  int64
#  44  Bwd Header Length           547557 non-null  int64
#  45  Fwd Packets/s               547557 non-null  float64
#  46  Bwd Packets/s               547557 non-null  float64
#  47  Packet Length Min           547557 non-null  int64
#  48  Packet Length Max           547557 non-null  int64
#  49  Packet Length Mean          547557 non-null  float64
#  50  Packet Length Std           547557 non-null  float64
#  51  Packet Length Variance      547557 non-null  float64
#  52  FIN Flag Count              547557 non-null  int64
#  53  SYN Flag Count              547557 non-null  int64
#  54  RST Flag Count              547557 non-null  int64
#  55  PSH Flag Count              547557 non-null  int64
#  56  ACK Flag Count              547557 non-null  int64
#  57  URG Flag Count              547557 non-null  int64
#  58  CWR Flag Count              547557 non-null  int64
#  59  ECE Flag Count              547557 non-null  int64
#  60  Down/Up Ratio               547557 non-null  float64
#  61  Average Packet Size         547557 non-null  float64
#  62  Fwd Segment Size Avg        547557 non-null  float64
#  63  Bwd Segment Size Avg        547557 non-null  float64
#  64  Fwd Bytes/Bulk Avg          547557 non-null  int64
#  65  Fwd Packet/Bulk Avg         547557 non-null  int64
#  66  Fwd Bulk Rate Avg           547557 non-null  int64
#  67  Bwd Bytes/Bulk Avg          547557 non-null  int64
#  68  Bwd Packet/Bulk Avg         547557 non-null  int64
#  69  Bwd Bulk Rate Avg           547557 non-null  int64
#  70  Subflow Fwd Packets         547557 non-null  int64
#  71  Subflow Fwd Bytes           547557 non-null  int64
#  72  Subflow Bwd Packets         547557 non-null  int64
#  73  Subflow Bwd Bytes           547557 non-null  int64
#  74  FWD Init Win Bytes          547557 non-null  int64
#  75  Bwd Init Win Bytes          547557 non-null  int64
#  76  Fwd Act Data Pkts           547557 non-null  int64
#  77  Fwd Seg Size Min            547557 non-null  int64
#  78  Active Mean                 547557 non-null  float64
#  79  Active Std                  547557 non-null  float64
#  80  Active Max                  547557 non-null  int64
#  81  Active Min                  547557 non-null  int64
#  82  Idle Mean                   547557 non-null  float64
#  83  Idle Std                    547557 non-null  float64
#  84  Idle Max                    547557 non-null  int64
#  85  Idle Min                    547557 non-null  int64
#  86  ICMP Code                   547557 non-null  int64
#  87  ICMP Type                   547557 non-null  int64
#  88  Total TCP Flow Time         547557 non-null  int64
#  89  Label                       547557 non-null  category
#  90  Attempted Category          547557 non-null  int64
# dtypes: category(4), datetime64[ns](1), float64(25), int64(61)
# memory usage: 412.1 MB

# %%
fdf
# Out:
#             id                                  Flow ID         Src IP  \
# 0            1  192.168.10.50-192.168.10.3-56108-3268-6  192.168.10.50
# 1            2   192.168.10.50-192.168.10.3-42144-389-6  192.168.10.50
# 2            3                    8.6.0.1-8.0.6.4-0-0-0        8.6.0.1
# 3            4   192.168.10.25-224.0.0.251-5353-5353-17  192.168.10.25
# 4            5   192.168.10.25-17.253.14.125-123-123-17  192.168.10.25
# ...        ...                                      ...            ...
# 547552  547553    172.16.0.1-192.168.10.50-64318-2222-6     172.16.0.1
# 547553  547554    172.16.0.1-192.168.10.50-33248-9040-6     172.16.0.1
# 547554  547555    172.16.0.1-192.168.10.50-44033-1272-6     172.16.0.1
# 547555  547556   192.168.10.16-192.168.10.3-64748-53-17  192.168.10.16
# 547556  547557  192.168.10.51-162.213.33.50-58853-443-6  192.168.10.51
#
#         Src Port         Dst IP  Dst Port  Protocol  \
# 0          56108   192.168.10.3      3268         6
# 1          42144   192.168.10.3       389         6
# 2              0        8.0.6.4         0         0
# 3           5353    224.0.0.251      5353        17
# 4            123  17.253.14.125       123        17
# ...          ...            ...       ...       ...
# 547552     64318  192.168.10.50      2222         6
# 547553     33248  192.168.10.50      9040         6
# 547554     44033  192.168.10.50      1272         6
# 547555     64748   192.168.10.3        53        17
# 547556     58853  162.213.33.50       443         6
#
#                          Timestamp  Flow Duration  Total Fwd Packet  ...  \
# 0       2017-07-07 11:59:50.315195      112740690                32  ...
# 1       2017-07-07 11:59:50.316273      112740560                32  ...
# 2       2017-07-07 12:00:31.388567      113757377               545  ...
# 3       2017-07-07 12:00:42.903850       91997219               388  ...
# 4       2017-07-07 12:00:42.430758       66966070                 6  ...
# ...                            ...            ...               ...  ...
# 547552  2017-07-07 18:09:11.499555             64                 1  ...
# 547553  2017-07-07 17:54:38.857717             76                 1  ...
# 547554  2017-07-07 17:52:03.285040             81                 1  ...
# 547555  2017-07-07 18:33:45.701233            297                 2  ...
# 547556  2017-07-07 13:46:39.176784        3295131                13  ...
#
#         Active Min     Idle Mean      Idle Std  Idle Max  Idle Min  ICMP Code  \
# 0              343  1.610540e+07  4.988048e+05  16399772  15375229         -1
# 1              285  1.610543e+07  4.987937e+05  16399782  15375263         -1
# 2               19  1.221036e+07  6.935824e+06  20757030   5504997         -1
# 3               16  1.319764e+07  5.826905e+06  19776791   5817470         -1
# 4          1968172  6.497443e+07  0.000000e+00  64974431  64974431         -1
# ...            ...           ...           ...       ...       ...        ...
# 547552           0  0.000000e+00  0.000000e+00         0         0         -1
# 547553           0  0.000000e+00  0.000000e+00         0         0         -1
# 547554           0  0.000000e+00  0.000000e+00         0         0         -1
# 547555           0  0.000000e+00  0.000000e+00         0         0         -1
# 547556           0  0.000000e+00  0.000000e+00         0         0         -1
#
#         ICMP Type  Total TCP Flow Time     Label  Attempted Category
# 0              -1            112740690    BENIGN                  -1
# 1              -1            112740560    BENIGN                  -1
# 2              -1                    0    BENIGN                  -1
# 3              -1                    0    BENIGN                  -1
# 4              -1                    0    BENIGN                  -1
# ...           ...                  ...       ...                 ...
# 547552         -1                   64  Portscan                  -1
# 547553         -1                   76  Portscan                  -1
# 547554         -1                   81  Portscan                  -1
# 547555         -1                    0    BENIGN                  -1
# 547556         -1              3295131    BENIGN                  -1
#
# [547557 rows x 91 columns]

# %%
fdf.describe()
# Out:
#                   id       Src Port       Dst Port       Protocol  \
# count  547557.000000  547557.000000  547557.000000  547557.000000
# mean   273779.000000   47158.825030    2826.089161       9.785144
# std    158066.235011   16039.868513    8604.258903       5.233530
# min         1.000000       0.000000       0.000000       0.000000
# 25%    136890.000000   39606.000000      53.000000       6.000000
# 50%    273779.000000   52332.000000      80.000000       6.000000
# 75%    410668.000000   59207.000000    1055.000000      17.000000
# max    547557.000000   65535.000000   65525.000000      17.000000
#
#        Flow Duration  Total Fwd Packet  Total Bwd packets  \
# count   5.475570e+05     547557.000000      547557.000000
# mean    9.252255e+06          8.726116           9.444566
# std     2.609339e+07        648.644128         874.427110
# min     1.000000e+00          0.000000           0.000000
# 25%     7.100000e+01          1.000000           1.000000
# 50%     3.114100e+04          2.000000           2.000000
# 75%     5.032396e+06          8.000000           5.000000
# max     1.200000e+08     207963.000000      284603.000000
#
#        Total Length of Fwd Packet  Total Length of Bwd Packet  \
# count               547557.000000                5.475570e+05
# mean                   374.740299                1.408719e+04
# std                   3088.263160                1.958688e+06
# min                      0.000000                0.000000e+00
# 25%                      0.000000                0.000000e+00
# 50%                     41.000000                1.680000e+02
# 75%                     88.000000                4.158000e+03
# max                 624776.000000                6.270395e+08
#
#        Fwd Packet Length Max  ...    Active Max    Active Min     Idle Mean  \
# count          547557.000000  ...  5.475570e+05  5.475570e+05  5.475570e+05
# mean              129.866494  ...  2.023936e+05  1.125818e+05  3.610678e+06
# std               495.923430  ...  1.071617e+06  6.682971e+05  1.149280e+07
# min                 0.000000  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 25%                 0.000000  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 50%                27.000000  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 75%                47.000000  ...  0.000000e+00  0.000000e+00  0.000000e+00
# max             24820.000000  ...  1.100975e+08  1.100975e+08  1.199912e+08
#
#            Idle Std      Idle Max      Idle Min      ICMP Code      ICMP Type  \
# count  5.475570e+05  5.475570e+05  5.475570e+05  547557.000000  547557.000000
# mean   1.455170e+05  3.716373e+06  3.451524e+06      -0.999262      -0.998444
# std    1.870863e+06  1.182962e+07  1.131402e+07       0.050051       0.093615
# min    0.000000e+00  0.000000e+00  0.000000e+00      -1.000000      -1.000000
# 25%    0.000000e+00  0.000000e+00  0.000000e+00      -1.000000      -1.000000
# 50%    0.000000e+00  0.000000e+00  0.000000e+00      -1.000000      -1.000000
# 75%    0.000000e+00  0.000000e+00  0.000000e+00      -1.000000      -1.000000
# max    7.663521e+07  1.199912e+08  1.199912e+08      10.000000       8.000000
#
#        Total TCP Flow Time  Attempted Category
# count         5.475570e+05       547557.000000
# mean          1.561664e+07           -0.985145
# std           1.899453e+08            0.171725
# min           0.000000e+00           -1.000000
# 25%           0.000000e+00           -1.000000
# 50%           4.800000e+01           -1.000000
# 75%           4.507917e+06           -1.000000
# max           2.676050e+10            1.000000
#
# [8 rows x 86 columns]

# %%
fdf.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547557 entries, 0 to 547556
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          547557 non-null  int64
#  1   Flow ID                     547557 non-null  object
#  2   Src IP                      547557 non-null  object
#  3   Src Port                    547557 non-null  int64
#  4   Dst IP                      547557 non-null  object
#  5   Dst Port                    547557 non-null  int64
#  6   Protocol                    547557 non-null  int64
#  7   Timestamp                   547557 non-null  object
#  8   Flow Duration               547557 non-null  int64
#  9   Total Fwd Packet            547557 non-null  int64
#  10  Total Bwd packets           547557 non-null  int64
#  11  Total Length of Fwd Packet  547557 non-null  int64
#  12  Total Length of Bwd Packet  547557 non-null  int64
#  13  Fwd Packet Length Max       547557 non-null  int64
#  14  Fwd Packet Length Min       547557 non-null  int64
#  15  Fwd Packet Length Mean      547557 non-null  float64
#  16  Fwd Packet Length Std       547557 non-null  float64
#  17  Bwd Packet Length Max       547557 non-null  int64
#  18  Bwd Packet Length Min       547557 non-null  int64
#  19  Bwd Packet Length Mean      547557 non-null  float64
#  20  Bwd Packet Length Std       547557 non-null  float64
#  21  Flow Bytes/s                547557 non-null  float64
#  22  Flow Packets/s              547557 non-null  float64
#  23  Flow IAT Mean               547557 non-null  float64
#  24  Flow IAT Std                547557 non-null  float64
#  25  Flow IAT Max                547557 non-null  int64
#  26  Flow IAT Min                547557 non-null  int64
#  27  Fwd IAT Total               547557 non-null  int64
#  28  Fwd IAT Mean                547557 non-null  float64
#  29  Fwd IAT Std                 547557 non-null  float64
#  30  Fwd IAT Max                 547557 non-null  int64
#  31  Fwd IAT Min                 547557 non-null  int64
#  32  Bwd IAT Total               547557 non-null  int64
#  33  Bwd IAT Mean                547557 non-null  float64
#  34  Bwd IAT Std                 547557 non-null  float64
#  35  Bwd IAT Max                 547557 non-null  int64
#  36  Bwd IAT Min                 547557 non-null  int64
#  37  Fwd PSH Flags               547557 non-null  int64
#  38  Bwd PSH Flags               547557 non-null  int64
#  39  Fwd URG Flags               547557 non-null  int64
#  40  Bwd URG Flags               547557 non-null  int64
#  41  Fwd RST Flags               547557 non-null  int64
#  42  Bwd RST Flags               547557 non-null  int64
#  43  Fwd Header Length           547557 non-null  int64
#  44  Bwd Header Length           547557 non-null  int64
#  45  Fwd Packets/s               547557 non-null  float64
#  46  Bwd Packets/s               547557 non-null  float64
#  47  Packet Length Min           547557 non-null  int64
#  48  Packet Length Max           547557 non-null  int64
#  49  Packet Length Mean          547557 non-null  float64
#  50  Packet Length Std           547557 non-null  float64
#  51  Packet Length Variance      547557 non-null  float64
#  52  FIN Flag Count              547557 non-null  int64
#  53  SYN Flag Count              547557 non-null  int64
#  54  RST Flag Count              547557 non-null  int64
#  55  PSH Flag Count              547557 non-null  int64
#  56  ACK Flag Count              547557 non-null  int64
#  57  URG Flag Count              547557 non-null  int64
#  58  CWR Flag Count              547557 non-null  int64
#  59  ECE Flag Count              547557 non-null  int64
#  60  Down/Up Ratio               547557 non-null  float64
#  61  Average Packet Size         547557 non-null  float64
#  62  Fwd Segment Size Avg        547557 non-null  float64
#  63  Bwd Segment Size Avg        547557 non-null  float64
#  64  Fwd Bytes/Bulk Avg          547557 non-null  int64
#  65  Fwd Packet/Bulk Avg         547557 non-null  int64
#  66  Fwd Bulk Rate Avg           547557 non-null  int64
#  67  Bwd Bytes/Bulk Avg          547557 non-null  int64
#  68  Bwd Packet/Bulk Avg         547557 non-null  int64
#  69  Bwd Bulk Rate Avg           547557 non-null  int64
#  70  Subflow Fwd Packets         547557 non-null  int64
#  71  Subflow Fwd Bytes           547557 non-null  int64
#  72  Subflow Bwd Packets         547557 non-null  int64
#  73  Subflow Bwd Bytes           547557 non-null  int64
#  74  FWD Init Win Bytes          547557 non-null  int64
#  75  Bwd Init Win Bytes          547557 non-null  int64
#  76  Fwd Act Data Pkts           547557 non-null  int64
#  77  Fwd Seg Size Min            547557 non-null  int64
#  78  Active Mean                 547557 non-null  float64
#  79  Active Std                  547557 non-null  float64
#  80  Active Max                  547557 non-null  int64
#  81  Active Min                  547557 non-null  int64
#  82  Idle Mean                   547557 non-null  float64
#  83  Idle Std                    547557 non-null  float64
#  84  Idle Max                    547557 non-null  int64
#  85  Idle Min                    547557 non-null  int64
#  86  ICMP Code                   547557 non-null  int64
#  87  ICMP Type                   547557 non-null  int64
#  88  Total TCP Flow Time         547557 non-null  int64
#  89  Label                       547557 non-null  object
#  90  Attempted Category          547557 non-null  int64
# dtypes: float64(25), int64(61), object(5)
# memory usage: 556.8 MB

# %%
ff = pd.read_parquet(
    path=os.path.join(project_path, 'data', 'cicids2017', 'friday.parquet'),
)

# %%
ff.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547557 entries, 0 to 547556
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          547557 non-null  int64
#  1   Flow ID                     547557 non-null  category
#  2   Src IP                      547557 non-null  category
#  3   Src Port                    547557 non-null  int64
#  4   Dst IP                      547557 non-null  category
#  5   Dst Port                    547557 non-null  int64
#  6   Protocol                    547557 non-null  int64
#  7   Timestamp                   547557 non-null  datetime64[ns]
#  8   Flow Duration               547557 non-null  int64
#  9   Total Fwd Packet            547557 non-null  int64
#  10  Total Bwd packets           547557 non-null  int64
#  11  Total Length of Fwd Packet  547557 non-null  int64
#  12  Total Length of Bwd Packet  547557 non-null  int64
#  13  Fwd Packet Length Max       547557 non-null  int64
#  14  Fwd Packet Length Min       547557 non-null  int64
#  15  Fwd Packet Length Mean      547557 non-null  float64
#  16  Fwd Packet Length Std       547557 non-null  float64
#  17  Bwd Packet Length Max       547557 non-null  int64
#  18  Bwd Packet Length Min       547557 non-null  int64
#  19  Bwd Packet Length Mean      547557 non-null  float64
#  20  Bwd Packet Length Std       547557 non-null  float64
#  21  Flow Bytes/s                547557 non-null  float64
#  22  Flow Packets/s              547557 non-null  float64
#  23  Flow IAT Mean               547557 non-null  float64
#  24  Flow IAT Std                547557 non-null  float64
#  25  Flow IAT Max                547557 non-null  int64
#  26  Flow IAT Min                547557 non-null  int64
#  27  Fwd IAT Total               547557 non-null  int64
#  28  Fwd IAT Mean                547557 non-null  float64
#  29  Fwd IAT Std                 547557 non-null  float64
#  30  Fwd IAT Max                 547557 non-null  int64
#  31  Fwd IAT Min                 547557 non-null  int64
#  32  Bwd IAT Total               547557 non-null  int64
#  33  Bwd IAT Mean                547557 non-null  float64
#  34  Bwd IAT Std                 547557 non-null  float64
#  35  Bwd IAT Max                 547557 non-null  int64
#  36  Bwd IAT Min                 547557 non-null  int64
#  37  Fwd PSH Flags               547557 non-null  int64
#  38  Bwd PSH Flags               547557 non-null  int64
#  39  Fwd URG Flags               547557 non-null  int64
#  40  Bwd URG Flags               547557 non-null  int64
#  41  Fwd RST Flags               547557 non-null  int64
#  42  Bwd RST Flags               547557 non-null  int64
#  43  Fwd Header Length           547557 non-null  int64
#  44  Bwd Header Length           547557 non-null  int64
#  45  Fwd Packets/s               547557 non-null  float64
#  46  Bwd Packets/s               547557 non-null  float64
#  47  Packet Length Min           547557 non-null  int64
#  48  Packet Length Max           547557 non-null  int64
#  49  Packet Length Mean          547557 non-null  float64
#  50  Packet Length Std           547557 non-null  float64
#  51  Packet Length Variance      547557 non-null  float64
#  52  FIN Flag Count              547557 non-null  int64
#  53  SYN Flag Count              547557 non-null  int64
#  54  RST Flag Count              547557 non-null  int64
#  55  PSH Flag Count              547557 non-null  int64
#  56  ACK Flag Count              547557 non-null  int64
#  57  URG Flag Count              547557 non-null  int64
#  58  CWR Flag Count              547557 non-null  int64
#  59  ECE Flag Count              547557 non-null  int64
#  60  Down/Up Ratio               547557 non-null  float64
#  61  Average Packet Size         547557 non-null  float64
#  62  Fwd Segment Size Avg        547557 non-null  float64
#  63  Bwd Segment Size Avg        547557 non-null  float64
#  64  Fwd Bytes/Bulk Avg          547557 non-null  int64
#  65  Fwd Packet/Bulk Avg         547557 non-null  int64
#  66  Fwd Bulk Rate Avg           547557 non-null  int64
#  67  Bwd Bytes/Bulk Avg          547557 non-null  int64
#  68  Bwd Packet/Bulk Avg         547557 non-null  int64
#  69  Bwd Bulk Rate Avg           547557 non-null  int64
#  70  Subflow Fwd Packets         547557 non-null  int64
#  71  Subflow Fwd Bytes           547557 non-null  int64
#  72  Subflow Bwd Packets         547557 non-null  int64
#  73  Subflow Bwd Bytes           547557 non-null  int64
#  74  FWD Init Win Bytes          547557 non-null  int64
#  75  Bwd Init Win Bytes          547557 non-null  int64
#  76  Fwd Act Data Pkts           547557 non-null  int64
#  77  Fwd Seg Size Min            547557 non-null  int64
#  78  Active Mean                 547557 non-null  float64
#  79  Active Std                  547557 non-null  float64
#  80  Active Max                  547557 non-null  int64
#  81  Active Min                  547557 non-null  int64
#  82  Idle Mean                   547557 non-null  float64
#  83  Idle Std                    547557 non-null  float64
#  84  Idle Max                    547557 non-null  int64
#  85  Idle Min                    547557 non-null  int64
#  86  ICMP Code                   547557 non-null  int64
#  87  ICMP Type                   547557 non-null  int64
#  88  Total TCP Flow Time         547557 non-null  int64
#  89  Label                       547557 non-null  category
#  90  Attempted Category          547557 non-null  int64
# dtypes: category(4), datetime64[ns](1), float64(25), int64(61)
# memory usage: 412.1 MB

# %%
# %timeit ff.groupby('Label').size()
# Out:
# 14.5 ms ± 162 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit f.groupby('Label').size()
# Out:
# 25.7 ms ± 1.11 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
f = pd.read_csv(os.path.join(project_path, 'data', 'cicids2017', 'friday.csv'), engine='pyarrow', da)
f.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547557 entries, 0 to 547556
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          547557 non-null  int64
#  1   Flow ID                     547557 non-null  object
#  2   Src IP                      547557 non-null  object
#  3   Src Port                    547557 non-null  int64
#  4   Dst IP                      547557 non-null  object
#  5   Dst Port                    547557 non-null  int64
#  6   Protocol                    547557 non-null  int64
#  7   Timestamp                   547557 non-null  object
#  8   Flow Duration               547557 non-null  int64
#  9   Total Fwd Packet            547557 non-null  int64
#  10  Total Bwd packets           547557 non-null  int64
#  11  Total Length of Fwd Packet  547557 non-null  int64
#  12  Total Length of Bwd Packet  547557 non-null  int64
#  13  Fwd Packet Length Max       547557 non-null  int64
#  14  Fwd Packet Length Min       547557 non-null  int64
#  15  Fwd Packet Length Mean      547557 non-null  float64
#  16  Fwd Packet Length Std       547557 non-null  float64
#  17  Bwd Packet Length Max       547557 non-null  int64
#  18  Bwd Packet Length Min       547557 non-null  int64
#  19  Bwd Packet Length Mean      547557 non-null  float64
#  20  Bwd Packet Length Std       547557 non-null  float64
#  21  Flow Bytes/s                547557 non-null  float64
#  22  Flow Packets/s              547557 non-null  float64
#  23  Flow IAT Mean               547557 non-null  float64
#  24  Flow IAT Std                547557 non-null  float64
#  25  Flow IAT Max                547557 non-null  int64
#  26  Flow IAT Min                547557 non-null  int64
#  27  Fwd IAT Total               547557 non-null  int64
#  28  Fwd IAT Mean                547557 non-null  float64
#  29  Fwd IAT Std                 547557 non-null  float64
#  30  Fwd IAT Max                 547557 non-null  int64
#  31  Fwd IAT Min                 547557 non-null  int64
#  32  Bwd IAT Total               547557 non-null  int64
#  33  Bwd IAT Mean                547557 non-null  float64
#  34  Bwd IAT Std                 547557 non-null  float64
#  35  Bwd IAT Max                 547557 non-null  int64
#  36  Bwd IAT Min                 547557 non-null  int64
#  37  Fwd PSH Flags               547557 non-null  int64
#  38  Bwd PSH Flags               547557 non-null  int64
#  39  Fwd URG Flags               547557 non-null  int64
#  40  Bwd URG Flags               547557 non-null  int64
#  41  Fwd RST Flags               547557 non-null  int64
#  42  Bwd RST Flags               547557 non-null  int64
#  43  Fwd Header Length           547557 non-null  int64
#  44  Bwd Header Length           547557 non-null  int64
#  45  Fwd Packets/s               547557 non-null  float64
#  46  Bwd Packets/s               547557 non-null  float64
#  47  Packet Length Min           547557 non-null  int64
#  48  Packet Length Max           547557 non-null  int64
#  49  Packet Length Mean          547557 non-null  float64
#  50  Packet Length Std           547557 non-null  float64
#  51  Packet Length Variance      547557 non-null  float64
#  52  FIN Flag Count              547557 non-null  int64
#  53  SYN Flag Count              547557 non-null  int64
#  54  RST Flag Count              547557 non-null  int64
#  55  PSH Flag Count              547557 non-null  int64
#  56  ACK Flag Count              547557 non-null  int64
#  57  URG Flag Count              547557 non-null  int64
#  58  CWR Flag Count              547557 non-null  int64
#  59  ECE Flag Count              547557 non-null  int64
#  60  Down/Up Ratio               547557 non-null  float64
#  61  Average Packet Size         547557 non-null  float64
#  62  Fwd Segment Size Avg        547557 non-null  float64
#  63  Bwd Segment Size Avg        547557 non-null  float64
#  64  Fwd Bytes/Bulk Avg          547557 non-null  int64
#  65  Fwd Packet/Bulk Avg         547557 non-null  int64
#  66  Fwd Bulk Rate Avg           547557 non-null  int64
#  67  Bwd Bytes/Bulk Avg          547557 non-null  int64
#  68  Bwd Packet/Bulk Avg         547557 non-null  int64
#  69  Bwd Bulk Rate Avg           547557 non-null  int64
#  70  Subflow Fwd Packets         547557 non-null  int64
#  71  Subflow Fwd Bytes           547557 non-null  int64
#  72  Subflow Bwd Packets         547557 non-null  int64
#  73  Subflow Bwd Bytes           547557 non-null  int64
#  74  FWD Init Win Bytes          547557 non-null  int64
#  75  Bwd Init Win Bytes          547557 non-null  int64
#  76  Fwd Act Data Pkts           547557 non-null  int64
#  77  Fwd Seg Size Min            547557 non-null  int64
#  78  Active Mean                 547557 non-null  float64
#  79  Active Std                  547557 non-null  float64
#  80  Active Max                  547557 non-null  int64
#  81  Active Min                  547557 non-null  int64
#  82  Idle Mean                   547557 non-null  float64
#  83  Idle Std                    547557 non-null  float64
#  84  Idle Max                    547557 non-null  int64
#  85  Idle Min                    547557 non-null  int64
#  86  ICMP Code                   547557 non-null  int64
#  87  ICMP Type                   547557 non-null  int64
#  88  Total TCP Flow Time         547557 non-null  int64
#  89  Label                       547557 non-null  object
#  90  Attempted Category          547557 non-null  int64
# dtypes: float64(25), int64(61), object(5)
# memory usage: 556.8 MB

# %%
ff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547557 entries, 0 to 547556
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          547557 non-null  int64[pyarrow]
#  1   Flow ID                     547557 non-null  string
#  2   Src IP                      547557 non-null  string
#  3   Src Port                    547557 non-null  int64[pyarrow]
#  4   Dst IP                      547557 non-null  string
#  5   Dst Port                    547557 non-null  int64[pyarrow]
#  6   Protocol                    547557 non-null  int64[pyarrow]
#  7   Timestamp                   547557 non-null  timestamp[ns][pyarrow]
#  8   Flow Duration               547557 non-null  int64[pyarrow]
#  9   Total Fwd Packet            547557 non-null  int64[pyarrow]
#  10  Total Bwd packets           547557 non-null  int64[pyarrow]
#  11  Total Length of Fwd Packet  547557 non-null  int64[pyarrow]
#  12  Total Length of Bwd Packet  547557 non-null  int64[pyarrow]
#  13  Fwd Packet Length Max       547557 non-null  int64[pyarrow]
#  14  Fwd Packet Length Min       547557 non-null  int64[pyarrow]
#  15  Fwd Packet Length Mean      547557 non-null  double[pyarrow]
#  16  Fwd Packet Length Std       547557 non-null  double[pyarrow]
#  17  Bwd Packet Length Max       547557 non-null  int64[pyarrow]
#  18  Bwd Packet Length Min       547557 non-null  int64[pyarrow]
#  19  Bwd Packet Length Mean      547557 non-null  double[pyarrow]
#  20  Bwd Packet Length Std       547557 non-null  double[pyarrow]
#  21  Flow Bytes/s                547557 non-null  double[pyarrow]
#  22  Flow Packets/s              547557 non-null  double[pyarrow]
#  23  Flow IAT Mean               547557 non-null  double[pyarrow]
#  24  Flow IAT Std                547557 non-null  double[pyarrow]
#  25  Flow IAT Max                547557 non-null  int64[pyarrow]
#  26  Flow IAT Min                547557 non-null  int64[pyarrow]
#  27  Fwd IAT Total               547557 non-null  int64[pyarrow]
#  28  Fwd IAT Mean                547557 non-null  double[pyarrow]
#  29  Fwd IAT Std                 547557 non-null  double[pyarrow]
#  30  Fwd IAT Max                 547557 non-null  int64[pyarrow]
#  31  Fwd IAT Min                 547557 non-null  int64[pyarrow]
#  32  Bwd IAT Total               547557 non-null  int64[pyarrow]
#  33  Bwd IAT Mean                547557 non-null  double[pyarrow]
#  34  Bwd IAT Std                 547557 non-null  double[pyarrow]
#  35  Bwd IAT Max                 547557 non-null  int64[pyarrow]
#  36  Bwd IAT Min                 547557 non-null  int64[pyarrow]
#  37  Fwd PSH Flags               547557 non-null  int64[pyarrow]
#  38  Bwd PSH Flags               547557 non-null  int64[pyarrow]
#  39  Fwd URG Flags               547557 non-null  int64[pyarrow]
#  40  Bwd URG Flags               547557 non-null  int64[pyarrow]
#  41  Fwd RST Flags               547557 non-null  int64[pyarrow]
#  42  Bwd RST Flags               547557 non-null  int64[pyarrow]
#  43  Fwd Header Length           547557 non-null  int64[pyarrow]
#  44  Bwd Header Length           547557 non-null  int64[pyarrow]
#  45  Fwd Packets/s               547557 non-null  double[pyarrow]
#  46  Bwd Packets/s               547557 non-null  double[pyarrow]
#  47  Packet Length Min           547557 non-null  int64[pyarrow]
#  48  Packet Length Max           547557 non-null  int64[pyarrow]
#  49  Packet Length Mean          547557 non-null  double[pyarrow]
#  50  Packet Length Std           547557 non-null  double[pyarrow]
#  51  Packet Length Variance      547557 non-null  double[pyarrow]
#  52  FIN Flag Count              547557 non-null  int64[pyarrow]
#  53  SYN Flag Count              547557 non-null  int64[pyarrow]
#  54  RST Flag Count              547557 non-null  int64[pyarrow]
#  55  PSH Flag Count              547557 non-null  int64[pyarrow]
#  56  ACK Flag Count              547557 non-null  int64[pyarrow]
#  57  URG Flag Count              547557 non-null  int64[pyarrow]
#  58  CWR Flag Count              547557 non-null  int64[pyarrow]
#  59  ECE Flag Count              547557 non-null  int64[pyarrow]
#  60  Down/Up Ratio               547557 non-null  double[pyarrow]
#  61  Average Packet Size         547557 non-null  double[pyarrow]
#  62  Fwd Segment Size Avg        547557 non-null  double[pyarrow]
#  63  Bwd Segment Size Avg        547557 non-null  double[pyarrow]
#  64  Fwd Bytes/Bulk Avg          547557 non-null  int64[pyarrow]
#  65  Fwd Packet/Bulk Avg         547557 non-null  int64[pyarrow]
#  66  Fwd Bulk Rate Avg           547557 non-null  int64[pyarrow]
#  67  Bwd Bytes/Bulk Avg          547557 non-null  int64[pyarrow]
#  68  Bwd Packet/Bulk Avg         547557 non-null  int64[pyarrow]
#  69  Bwd Bulk Rate Avg           547557 non-null  int64[pyarrow]
#  70  Subflow Fwd Packets         547557 non-null  int64[pyarrow]
#  71  Subflow Fwd Bytes           547557 non-null  int64[pyarrow]
#  72  Subflow Bwd Packets         547557 non-null  int64[pyarrow]
#  73  Subflow Bwd Bytes           547557 non-null  int64[pyarrow]
#  74  FWD Init Win Bytes          547557 non-null  int64[pyarrow]
#  75  Bwd Init Win Bytes          547557 non-null  int64[pyarrow]
#  76  Fwd Act Data Pkts           547557 non-null  int64[pyarrow]
#  77  Fwd Seg Size Min            547557 non-null  int64[pyarrow]
#  78  Active Mean                 547557 non-null  double[pyarrow]
#  79  Active Std                  547557 non-null  double[pyarrow]
#  80  Active Max                  547557 non-null  int64[pyarrow]
#  81  Active Min                  547557 non-null  int64[pyarrow]
#  82  Idle Mean                   547557 non-null  double[pyarrow]
#  83  Idle Std                    547557 non-null  double[pyarrow]
#  84  Idle Max                    547557 non-null  int64[pyarrow]
#  85  Idle Min                    547557 non-null  int64[pyarrow]
#  86  ICMP Code                   547557 non-null  int64[pyarrow]
#  87  ICMP Type                   547557 non-null  int64[pyarrow]
#  88  Total TCP Flow Time         547557 non-null  int64[pyarrow]
#  89  Label                       547557 non-null  string
#  90  Attempted Category          547557 non-null  int64[pyarrow]
# dtypes: double[pyarrow](25), int64[pyarrow](61), string(4), timestamp[ns][pyarrow](1)
# memory usage: 421.0 MB

# %%
ff['Label'].value_counts()
# Out:
# Label
# BENIGN                288544
# Portscan              159066
# DDoS                   95144
# Botnet - Attempted      4067
# Botnet                   736
# Name: count, dtype: int64[pyarrow]

# %%
ff['Label'] = ff['Label'].astype('string[pyarrow]')

# %%
ff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547557 entries, 0 to 547556
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          547557 non-null  int64[pyarrow]
#  1   Flow ID                     547557 non-null  string
#  2   Src IP                      547557 non-null  string
#  3   Src Port                    547557 non-null  int64[pyarrow]
#  4   Dst IP                      547557 non-null  string
#  5   Dst Port                    547557 non-null  int64[pyarrow]
#  6   Protocol                    547557 non-null  int64[pyarrow]
#  7   Timestamp                   547557 non-null  timestamp[ns][pyarrow]
#  8   Flow Duration               547557 non-null  int64[pyarrow]
#  9   Total Fwd Packet            547557 non-null  int64[pyarrow]
#  10  Total Bwd packets           547557 non-null  int64[pyarrow]
#  11  Total Length of Fwd Packet  547557 non-null  int64[pyarrow]
#  12  Total Length of Bwd Packet  547557 non-null  int64[pyarrow]
#  13  Fwd Packet Length Max       547557 non-null  int64[pyarrow]
#  14  Fwd Packet Length Min       547557 non-null  int64[pyarrow]
#  15  Fwd Packet Length Mean      547557 non-null  double[pyarrow]
#  16  Fwd Packet Length Std       547557 non-null  double[pyarrow]
#  17  Bwd Packet Length Max       547557 non-null  int64[pyarrow]
#  18  Bwd Packet Length Min       547557 non-null  int64[pyarrow]
#  19  Bwd Packet Length Mean      547557 non-null  double[pyarrow]
#  20  Bwd Packet Length Std       547557 non-null  double[pyarrow]
#  21  Flow Bytes/s                547557 non-null  double[pyarrow]
#  22  Flow Packets/s              547557 non-null  double[pyarrow]
#  23  Flow IAT Mean               547557 non-null  double[pyarrow]
#  24  Flow IAT Std                547557 non-null  double[pyarrow]
#  25  Flow IAT Max                547557 non-null  int64[pyarrow]
#  26  Flow IAT Min                547557 non-null  int64[pyarrow]
#  27  Fwd IAT Total               547557 non-null  int64[pyarrow]
#  28  Fwd IAT Mean                547557 non-null  double[pyarrow]
#  29  Fwd IAT Std                 547557 non-null  double[pyarrow]
#  30  Fwd IAT Max                 547557 non-null  int64[pyarrow]
#  31  Fwd IAT Min                 547557 non-null  int64[pyarrow]
#  32  Bwd IAT Total               547557 non-null  int64[pyarrow]
#  33  Bwd IAT Mean                547557 non-null  double[pyarrow]
#  34  Bwd IAT Std                 547557 non-null  double[pyarrow]
#  35  Bwd IAT Max                 547557 non-null  int64[pyarrow]
#  36  Bwd IAT Min                 547557 non-null  int64[pyarrow]
#  37  Fwd PSH Flags               547557 non-null  int64[pyarrow]
#  38  Bwd PSH Flags               547557 non-null  int64[pyarrow]
#  39  Fwd URG Flags               547557 non-null  int64[pyarrow]
#  40  Bwd URG Flags               547557 non-null  int64[pyarrow]
#  41  Fwd RST Flags               547557 non-null  int64[pyarrow]
#  42  Bwd RST Flags               547557 non-null  int64[pyarrow]
#  43  Fwd Header Length           547557 non-null  int64[pyarrow]
#  44  Bwd Header Length           547557 non-null  int64[pyarrow]
#  45  Fwd Packets/s               547557 non-null  double[pyarrow]
#  46  Bwd Packets/s               547557 non-null  double[pyarrow]
#  47  Packet Length Min           547557 non-null  int64[pyarrow]
#  48  Packet Length Max           547557 non-null  int64[pyarrow]
#  49  Packet Length Mean          547557 non-null  double[pyarrow]
#  50  Packet Length Std           547557 non-null  double[pyarrow]
#  51  Packet Length Variance      547557 non-null  double[pyarrow]
#  52  FIN Flag Count              547557 non-null  int64[pyarrow]
#  53  SYN Flag Count              547557 non-null  int64[pyarrow]
#  54  RST Flag Count              547557 non-null  int64[pyarrow]
#  55  PSH Flag Count              547557 non-null  int64[pyarrow]
#  56  ACK Flag Count              547557 non-null  int64[pyarrow]
#  57  URG Flag Count              547557 non-null  int64[pyarrow]
#  58  CWR Flag Count              547557 non-null  int64[pyarrow]
#  59  ECE Flag Count              547557 non-null  int64[pyarrow]
#  60  Down/Up Ratio               547557 non-null  double[pyarrow]
#  61  Average Packet Size         547557 non-null  double[pyarrow]
#  62  Fwd Segment Size Avg        547557 non-null  double[pyarrow]
#  63  Bwd Segment Size Avg        547557 non-null  double[pyarrow]
#  64  Fwd Bytes/Bulk Avg          547557 non-null  int64[pyarrow]
#  65  Fwd Packet/Bulk Avg         547557 non-null  int64[pyarrow]
#  66  Fwd Bulk Rate Avg           547557 non-null  int64[pyarrow]
#  67  Bwd Bytes/Bulk Avg          547557 non-null  int64[pyarrow]
#  68  Bwd Packet/Bulk Avg         547557 non-null  int64[pyarrow]
#  69  Bwd Bulk Rate Avg           547557 non-null  int64[pyarrow]
#  70  Subflow Fwd Packets         547557 non-null  int64[pyarrow]
#  71  Subflow Fwd Bytes           547557 non-null  int64[pyarrow]
#  72  Subflow Bwd Packets         547557 non-null  int64[pyarrow]
#  73  Subflow Bwd Bytes           547557 non-null  int64[pyarrow]
#  74  FWD Init Win Bytes          547557 non-null  int64[pyarrow]
#  75  Bwd Init Win Bytes          547557 non-null  int64[pyarrow]
#  76  Fwd Act Data Pkts           547557 non-null  int64[pyarrow]
#  77  Fwd Seg Size Min            547557 non-null  int64[pyarrow]
#  78  Active Mean                 547557 non-null  double[pyarrow]
#  79  Active Std                  547557 non-null  double[pyarrow]
#  80  Active Max                  547557 non-null  int64[pyarrow]
#  81  Active Min                  547557 non-null  int64[pyarrow]
#  82  Idle Mean                   547557 non-null  double[pyarrow]
#  83  Idle Std                    547557 non-null  double[pyarrow]
#  84  Idle Max                    547557 non-null  int64[pyarrow]
#  85  Idle Min                    547557 non-null  int64[pyarrow]
#  86  ICMP Code                   547557 non-null  int64[pyarrow]
#  87  ICMP Type                   547557 non-null  int64[pyarrow]
#  88  Total TCP Flow Time         547557 non-null  int64[pyarrow]
#  89  Label                       547557 non-null  string
#  90  Attempted Category          547557 non-null  int64[pyarrow]
# dtypes: double[pyarrow](25), int64[pyarrow](61), string(4), timestamp[ns][pyarrow](1)
# memory usage: 421.0 MB
